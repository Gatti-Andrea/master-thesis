# %%
# Show plots inline, and load main getdist plot module and samples class
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import sys, os
sys.path.insert(0,os.path.realpath(os.path.join(os.getcwd(),'..')))
from getdist import plots, MCSamples
import getdist
import camb
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import IPython
print('GetDist Version: %s, Matplotlib version: %s'%(getdist.__version__, plt.matplotlib.__version__))
# Out:
# /home/andrewcats/anaconda3/envs/conda_andrea_g/lib/python3.9/site-packages/numpy/_core/getlimits.py:545: UserWarning: Signature b'\x00\xd0\xcc\xcc\xcc\xcc\xcc\xcc\xfb\xbf\x00\x00\x00\x00\x00\x00' for <class 'numpy.longdouble'> does not match any known type: falling back to type probe function.
# This warnings indicates broken support for the dtype!
#   machar = _get_machar(dtype)
# GetDist Version: 1.5.4, Matplotlib version: 3.9.2

# %%
# Loading samples
#w0wacdm
samples_planck = getdist.mcsamples.loadMCSamples(file_root=os.path.join('/home/andrewcats/tesi_magistrale/eftcamb/eftcamb_exponential/w0wacdm_eft_exp/desidr2', '1_EXP_w0wa_desi'), settings={'ignore_rows':0.3})
#print('Parameters: ', samples.paramNames.names)
param_names_planck = [param.name for param in samples_planck.paramNames.names]
print(param_names_planck)
# Out:
# ['H0', 'logA', 'ns', 'ombh2', 'omch2', 'tau', 'w', 'wa', 'EFT_lambda', 'A', 'As', 'DHBBN', 'YHe', 'Y_p', 'age', 'clamp', 'omega_de', 'omegam', 'omegamh2', 'rdrag', 's8h5', 'S8_optimal', 's8omegamp25', 's8omegamp5', 'sigma8', 'thetastar', 'chi2__BAO', 'chi2', 'chi2__bao.desi_dr2.desi_bao_all']

# %%
g = plots.get_single_plotter()
g.plot_2d(samples_planck, ['omegam', 'H0'])
# Out:
# ((np.float64(0.2672158616313751), np.float64(0.34737685836862486)),
#  (np.float64(41.36992830409914), 100.0))
